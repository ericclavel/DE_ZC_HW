# %%
from pyspark import SparkConf
from pyspark.sql import SparkSession

conf = SparkConf() \
    .setMaster("local[*]") \
    .setAppName("test") \
    .set("spark.jars", "data/lib/gcs-connector-3.1.18-shaded.jar") \
    .set("spark.hadoop.fs.gs.auth.type", "APPLICATION_DEFAULT")

spark = SparkSession.builder \
    .config(conf=conf) \
    .getOrCreate()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# WARNING: package sun.security.action not in java.base
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 26/08/25 14:47:10 WARN Utils: Your hostname, DESKTOP-JCM8NP2, resolves to a loopback address: 127.0.1.1; using 10.255.255.254 instead (on interface lo)
# 26/08/25 14:47:10 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# 26/08/25 14:47:10 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).

# %%
sc = spark.sparkContext

hadoop_conf = sc._jsc.hadoopConfiguration()

hadoop_conf.set(
    "fs.AbstractFileSystem.gs.impl",
    "com.google.cloud.hadoop.fs.gcs.GoogleHadoopFS"
)

hadoop_conf.set(
    "fs.gs.impl",
    "com.google.cloud.hadoop.fs.gcs.GoogleHadoopFileSystem"
)

hadoop_conf.set(
    "fs.gs.auth.type",
    "APPLICATION_DEFAULT"
)

# %%
df_green = spark.read.parquet(
    "gs://arctic-operand-398220-eclavel-hw/pq/green/2021/01"
)
# Out:
# 26/08/25 14:47:24 WARN FileSystem: Failed to initialize filesystem gs://arctic-operand-398220-eclavel-hw/pq/green/2021/01: java.lang.NumberFormatException: For input string: "64m"
# 26/08/25 14:47:24 WARN FileStreamSink: Assume no metadata directory. Error while looking for metadata directory in the path: gs://arctic-operand-398220-eclavel-hw/pq/green/2021/01.
# java.lang.NumberFormatException: For input string: "64m"
# 	at java.base/java.lang.NumberFormatException.forInputString(NumberFormatException.java:67)
# 	at java.base/java.lang.Long.parseLong(Long.java:594)
# 	at java.base/java.lang.Long.parseLong(Long.java:698)
# 	at org.apache.hadoop.conf.Configuration.getLong(Configuration.java:1591)
# 	at com.google.cloud.hadoop.repackaged.gcs.com.google.cloud.hadoop.util.HadoopConfigurationProperty.get(HadoopConfigurationProperty.java:81)
# 	at com.google.cloud.hadoop.fs.gcs.GoogleHadoopFileSystem.initialize(GoogleHadoopFileSystem.java:315)
# ...

# %%
conf = SparkConf() \
    .setMaster("local[*]") \
    .setAppName("test") \
    .set(
        "spark.jars",
        "data/lib/gcs-connector-hadoop3-latest.jar"
    ) \
    .set(
        "spark.hadoop.fs.gs.auth.type",
        "APPLICATION_DEFAULT"
    )

# %%
sc = spark.sparkContext

hadoop_conf = sc._jsc.hadoopConfiguration()

hadoop_conf.set(
    "fs.AbstractFileSystem.gs.impl",
    "com.google.cloud.hadoop.fs.gcs.GoogleHadoopFS"
)

hadoop_conf.set(
    "fs.gs.impl",
    "com.google.cloud.hadoop.fs.gcs.GoogleHadoopFileSystem"
)

hadoop_conf.set(
    "fs.gs.auth.type",
    "APPLICATION_DEFAULT"
)

# %%
spark = SparkSession.builder \
    .config(conf=sc.getConf()) \
    .getOrCreate()

# %%
import os

os.path.exists("data/lib/gcs-connector-hadoop3-latest.jar")
# Out:
# True

# %%
spark.stop()

# %%
df_green = spark.read.parquet(
    "gs://arctic-operand-398220-eclavel-hw/pq/green/2021/01"
)
# Out:
# 26/08/25 14:21:28 WARN FileStreamSink: Assume no metadata directory. Error while looking for metadata directory in the path: gs://arctic-operand-398220-eclavel-hw/pq/green/2021/01.
# java.lang.RuntimeException: java.lang.ClassNotFoundException: Class com.google.cloud.hadoop.fs.gcs.GoogleHadoopFileSystem not found
# 	at org.apache.hadoop.conf.Configuration.getClass(Configuration.java:2724)
# 	at org.apache.hadoop.fs.FileSystem.getFileSystemClass(FileSystem.java:3574)
# 	at org.apache.hadoop.fs.FileSystem.createFileSystem(FileSystem.java:3617)
# 	at org.apache.hadoop.fs.FileSystem$Cache.getInternal(FileSystem.java:3721)
# 	at org.apache.hadoop.fs.FileSystem$Cache.get(FileSystem.java:3672)
# 	at org.apache.hadoop.fs.FileSystem.get(FileSystem.java:558)
# 	at org.apache.hadoop.fs.Path.getFileSystem(Path.java:373)
# 	at org.apache.spark.sql.execution.streaming.sinks.FileStreamSink$.hasMetadata(FileStreamSink.scala:57)
# ...

# %%
df_green = spark.read.parquet('gs://arctic-operand-398220-eclavel-hw/pq/green/*/*')
# Out:
# 26/08/25 14:13:45 WARN FileStreamSink: Assume no metadata directory. Error while looking for metadata directory in the path: gs://arctic-operand-398220-eclavel-hw/pq/green/*/*.
# java.lang.RuntimeException: java.lang.ClassNotFoundException: Class com.google.cloud.hadoop.fs.gcs.GoogleHadoopFileSystem not found
# 	at org.apache.hadoop.conf.Configuration.getClass(Configuration.java:2724)
# 	at org.apache.hadoop.fs.FileSystem.getFileSystemClass(FileSystem.java:3574)
# 	at org.apache.hadoop.fs.FileSystem.createFileSystem(FileSystem.java:3617)
# 	at org.apache.hadoop.fs.FileSystem$Cache.getInternal(FileSystem.java:3721)
# 	at org.apache.hadoop.fs.FileSystem$Cache.get(FileSystem.java:3672)
# 	at org.apache.hadoop.fs.FileSystem.get(FileSystem.java:558)
# 	at org.apache.hadoop.fs.Path.getFileSystem(Path.java:373)
# 	at org.apache.spark.sql.execution.streaming.sinks.FileStreamSink$.hasMetadata(FileStreamSink.scala:57)
# ...

# %%
from pathlib import Path

paths = [str(p) for p in Path("data/pq/green/2021").iterdir() if p.is_dir()]

df_green = spark.read.parquet(*paths)

# %%
from pathlib import Path

paths = [str(p) for p in Path("data/pq/yellow/2021").iterdir() if p.is_dir()]

df_yellow = spark.read.parquet(*paths)

# %%
df_green.columns
# Out:
# ['VendorID',
#  'pickup_datetime',
#  'dropoff_datetime',
#  'store_and_fwd_flag',
#  'RatecodeID',
#  'PULocationID',
#  'DOLocationID',
#  'passenger_count',
#  'trip_distance',
#  'fare_amount',
#  'extra',
#  'mta_tax',
#  'tip_amount',
#  'tolls_amount',
#  'ehail_fee',
#  'improvement_surcharge',
#  'total_amount',
#  'payment_type',
#  'trip_type',
#  'congestion_surcharge']

# %%
df_green = df_green \
    .withColumnRenamed('lpep_pickup_datetime', 'pickup_datetime') \
    .withColumnRenamed('lpep_dropoff_datetime', 'dropoff_datetime')

# %%
df_yellow.columns
# Out:
# ['VendorID',
#  'pickup_datetime',
#  'dropoff_datetime',
#  'passenger_count',
#  'trip_distance',
#  'RatecodeID',
#  'store_and_fwd_flag',
#  'PULocationID',
#  'DOLocationID',
#  'payment_type',
#  'fare_amount',
#  'extra',
#  'mta_tax',
#  'tip_amount',
#  'tolls_amount',
#  'improvement_surcharge',
#  'total_amount',
#  'congestion_surcharge']

# %%
df_yellow = df_yellow \
    .withColumnRenamed('tpep_pickup_datetime', 'pickup_datetime') \
    .withColumnRenamed('tpep_dropoff_datetime', 'dropoff_datetime')

# %%
common_columns = []

yellow_columns = set(df_yellow.columns)

for col in df_green.columns:
    if col in yellow_columns:
        common_columns.append(col)

# %%
common_columns
# Out:
# ['VendorID',
#  'pickup_datetime',
#  'dropoff_datetime',
#  'store_and_fwd_flag',
#  'RatecodeID',
#  'PULocationID',
#  'DOLocationID',
#  'passenger_count',
#  'trip_distance',
#  'fare_amount',
#  'extra',
#  'mta_tax',
#  'tip_amount',
#  'tolls_amount',
#  'improvement_surcharge',
#  'total_amount',
#  'payment_type',
#  'congestion_surcharge']

# %%
from pyspark.sql import functions as F

# %%
df_green_sel = df_green \
    .select(common_columns) \
    .withColumn('service_type', F.lit('green'))

# %%
df_yellow_sel = df_yellow \
    .select(common_columns) \
    .withColumn('service_type', F.lit('yellow'))

# %%
df_trips_data = df_green_sel.unionAll(df_yellow_sel)

# %%
df_trips_data.groupBy('service_type').count().show()
# Out:
# [Stage 6:===============================>                          (7 + 6) / 13]
# +------------+--------+
# |service_type|   count|
# +------------+--------+
# |       green|  570466|
# |      yellow|15000700|
# +------------+--------+

# %%
df_trips_data.createOrReplaceTempView('trips_data')

# %%
spark.sql("""
SELECT
    service_type,
    count(1)
FROM 
    trips_data
GROUP BY
    service_type

""").show()
# Out:
# [Stage 10:===================================================>    (12 + 1) / 13]
# +------------+--------+
# |service_type|count(1)|
# +------------+--------+
# |       green|  570466|
# |      yellow|15000700|
# +------------+--------+

# %%
df_result = spark.sql("""
SELECT 
    -- Revenue grouping 
    PULocationID AS revenue_zone,
    date_trunc('month', pickup_datetime) AS revenue_month, 
    service_type, 

    -- Revenue calculation 
    SUM(fare_amount) AS revenue_monthly_fare,
    SUM(extra) AS revenue_monthly_extra,
    SUM(mta_tax) AS revenue_monthly_mta_tax,
    SUM(tip_amount) AS revenue_monthly_tip_amount,
    SUM(tolls_amount) AS revenue_monthly_tolls_amount,
    SUM(improvement_surcharge) AS revenue_monthly_improvement_surcharge,
    SUM(total_amount) AS revenue_monthly_total_amount,
    SUM(congestion_surcharge) AS revenue_monthly_congestion_surcharge,

    -- Additional calculations
    AVG(passenger_count) AS avg_monthly_passenger_count,
    AVG(trip_distance) AS avg_monthly_trip_distance
FROM
    trips_data
GROUP BY
    revenue_zone, revenue_month, service_type
""")

# %%
df_result.coalesce(1).write.parquet('data/report/revenue/', mode='overwrite')

# %%
set(df_yellow.columns) & set(df_green.columns)
# Out:
# {'DOLocationID',
#  'PULocationID',
#  'RatecodeID',
#  'VendorID',
#  'congestion_surcharge',
#  'extra',
#  'fare_amount',
#  'improvement_surcharge',
#  'mta_tax',
#  'passenger_count',
#  'payment_type',
#  'store_and_fwd_flag',
#  'tip_amount',
#  'tolls_amount',
#  'total_amount',
#  'trip_distance'}
